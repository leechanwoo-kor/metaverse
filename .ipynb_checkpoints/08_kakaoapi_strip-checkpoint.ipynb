# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# 라이브러리 추가
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 꼬꼬마 형태소 분석기
from konlpy.tag import Kkma
kkma = Kkma()

# %%
# '메타버스'가 언급된 카카오 블로그, 카페 글
df = pd.read_excel('/Users/charles/git/metaverse/data/kakaoapi.xlsx', sheet_name='Sheet1').drop(['Unnamed: 0'], axis=1)
df[['title']].to_csv('/Users/charles/git/metaverse/data/kakaoapi.txt', index=False, header=False)
f = open("/Users/charles/git/metaverse/data/kakaoapi.txt", 'r', encoding='UTF-8')
lines = f.readlines()
f.close()

# %%
# 단어 2차원 리스트
dataset = []
for i in range(len(lines)):
    dataset.append(kkma.nouns(lines[i]))
dataset = [[y for y in x if not len(y)==1] for x in dataset]   # 2자 이상 
dataset = [[y for y in x if not y.isdigit()] for x in dataset] # 숫자판별
dataset[:10]
# Out:
# [['메타', '메타버스', '버스', '관련주', '정리'],
#  ['메타', '메타버스', '버스', '국내', '국내순위', '순위', '확인'],
#  ['메타', '메타버스', '버스', '관련주', '총정리', '정리'],
#  ['메타', '메타버스', '버스', '정리'],
#  ['메타', '메타버스', '버스'],
#  ['메타', '메타버스', '버스', '관련주', '총정리', '정리'],
#  ['메타', '메타버스게임', '버스', '게임', '관련주', '총정리', '정리'],
#  ['메타', '메타버스플랫폼', '버스', '플랫폼', '관련주', '총정리', '정리'],
#  ['메타', '메타버스', '버스', '게임', '게임주', '총정리', '정리'],
#  ['메타', '메타버스', '버스', '필수', '필수정리', '정리']]

# %%
# Word2Vec 불러오기
from gensim.models.word2vec import Word2Vec

# %%
# 모형 구축
model = Word2Vec(dataset,
                 sg=1,           # Skip-gram 적용: 중심 단어로 주변 단어를 예측
                 window=5,       # 중심 단어로부터 좌우 5개 단어까지 학습에 적용
                 min_count=1     # 전체문서에서 최소 1회 이상 출현단어로 학습 진행
                )
model.init_sims(replace=True)

# %%
# 단어간 유사도
print("메타버스와 가상현실 단어간 유사도는 %.2f 입니다." % (model.wv.similarity('메타버스', '가상현실')))
# Out:
# 메타버스와 가상현실 단어간 유사도는 0.97 입니다.

# %%
# 가장 유사한 단어 100개
df = pd.DataFrame(model.wv.most_similar("메타버스", topn=100), columns=['단어', '유사도'])
df.head(60)
# Out:
#           단어       유사도
# 0         메타  0.994862
# 1         버스  0.994759
# 2         사업  0.991661
# 3         주가  0.989857
# 4         관련  0.988577
# 5         전망  0.987993
# 6         게임  0.987885
# 7         블록  0.987657
# 8         체인  0.987300
# 9         투자  0.986887
# 10        정리  0.986687
# 11        특강  0.985885
# 12        활용  0.985708
# 13        국내  0.985693
# 14        기업  0.985645
# 15       관련주  0.985424
# 16        추진  0.985205
# 17        테크  0.985195
# 18        테마  0.984728
# 19        미래  0.984156
# 20        주식  0.984148
# 21       네이버  0.984135
# 22      블록체인  0.984048
# 23        세계  0.983797
# 24       핀테크  0.983412
# 25        수혜  0.983288
# 26        세상  0.983128
# 27        산업  0.982934
# 28        페토  0.982930
# 29       청소년  0.982869
# 30        종목  0.982789
# 31       대학생  0.982736
# 32       콘텐츠  0.982726
# 33        분석  0.982550
# 34        우리  0.982548
# 35       컴퓨터  0.982073
# 36        시장  0.981980
# 37        핵심  0.981455
# 38      로블록스  0.981399
# 39      페이스북  0.981397
# 40        교육  0.981235
# 41        활동  0.981066
# 42       페이스  0.981065
# 43        한컴  0.981038
# 44      스튜디오  0.981033
# 45  예비청소년지도사  0.980880
# 46       디지털  0.980778
# 47        삼성  0.980758
# 48        교회  0.980746
# 49        학생  0.980584
# 50       이재명  0.980545
# 51        환경  0.980280
# 52        애플  0.980280
# 53       카카오  0.980267
# 54       미디어  0.980225
# 55        체험  0.980205
# 56        변경  0.980147
# 57        신규  0.980132
# 58      삼성전자  0.980126
# 59       대학원  0.980037

# %%
kw_list = ['메타', '주가', '게임', '블록체인', '로블록스'
           '페이스북', '디지털', '가상']
df = df[df['단어'].isin(kw_list)]
df
# Out:
#       단어       유사도
# 0     메타  0.994862
# 3     주가  0.989857
# 6     게임  0.987885
# 22  블록체인  0.984048
# 46   디지털  0.980778

# %%
# 가장 유사한 단어 100개
df1 = pd.DataFrame(model.wv.most_similar(df.iloc[0]['단어'], topn=100), columns=['단어', df.iloc[0]['단어']])
df2 = pd.DataFrame(model.wv.most_similar(df.iloc[1]['단어'], topn=100), columns=['단어', df.iloc[1]['단어']])
df3 = pd.DataFrame(model.wv.most_similar(df.iloc[2]['단어'], topn=100), columns=['단어', df.iloc[2]['단어']])
df4 = pd.DataFrame(model.wv.most_similar(df.iloc[3]['단어'], topn=100), columns=['단어', df.iloc[3]['단어']])
df5 = pd.DataFrame(model.wv.most_similar(df.iloc[4]['단어'], topn=100), columns=['단어', df.iloc[4]['단어']])
dfs = [df.set_index(['단어']) for df in [df1, df2, df3, df4, df5]]
df5 = pd.concat(dfs, join='inner', axis=1).reset_index()
df5.head(10)
# Out:
#    단어        메타        주가        게임      블록체인       디지털
# 0  블록  0.987659  0.992719  0.995182  0.995896  0.994297
# 1  기업  0.987414  0.994940  0.994796  0.992791  0.994204
# 2  투자  0.986767  0.993840  0.995403  0.993867  0.994512
# 3  특강  0.986123  0.993681  0.995094  0.992846  0.993749
# 4  주식  0.986053  0.993202  0.994467  0.993301  0.994020
# 5  추진  0.985849  0.994745  0.994233  0.993004  0.995205
# 6  테크  0.985722  0.994817  0.995402  0.993694  0.995674
# 7  활용  0.985683  0.992992  0.994583  0.992665  0.994423
# 8  세계  0.984570  0.993530  0.994331  0.992854  0.993895
# 9  미래  0.984514  0.994570  0.995867  0.993299  0.996340

# %%
# 단어 평균 컬럼 추가
df5['전체'] = df5.mean(numeric_only=True, axis=1)
df = df5.sort_values(by='전체', ascending=False); df = df[:30]
df.head(10)
# Out:
#      단어        메타        주가        게임      블록체인       디지털        전체
# 0    블록  0.987659  0.992719  0.995182  0.995896  0.994297  0.993151
# 6    테크  0.985722  0.994817  0.995402  0.993694  0.995674  0.993062
# 9    미래  0.984514  0.994570  0.995867  0.993299  0.996340  0.992918
# 2    투자  0.986767  0.993840  0.995403  0.993867  0.994512  0.992878
# 1    기업  0.987414  0.994940  0.994796  0.992791  0.994204  0.992829
# 5    추진  0.985849  0.994745  0.994233  0.993004  0.995205  0.992607
# 11  청소년  0.983645  0.994222  0.995347  0.993470  0.995905  0.992518
# 3    특강  0.986123  0.993681  0.995094  0.992846  0.993749  0.992298
# 4    주식  0.986053  0.993202  0.994467  0.993301  0.994020  0.992209
# 7    활용  0.985683  0.992992  0.994583  0.992665  0.994423  0.992069

# %%
# 플롯 설정
sns.set(style='whitegrid', font='KoPubDotum', font_scale=1.3)
g = sns.PairGrid(df.sort_values("전체", ascending=False), x_vars=df.columns[1:6], y_vars=["단어"])
g.fig.set_size_inches(16,16)

# 스트립플롯 함수를 이용한 닷 플롯
g.map(sns.stripplot,
      size=10,
      orient="h",
      palette="ch:s=1,r=-.1,h=1_r",
      linewidth=1,
      edgecolor="w")
g.set(xlim=(0.95, 1), xlabel="유사도", ylabel="")
titles = df.columns[1:6]

for ax, title in zip(g.axes.flat, titles):
    ax.set(title=title)                        # 축 제목 설정
    ax.xaxis.grid(False); ax.yaxis.grid(True) # 수평 격자 설정

sns.despine(left=True, bottom=True)
plt.savefig('/Users/charles/git/metaverse/image/kakaoapi_stripplot.png', bbox_inches='tight')
